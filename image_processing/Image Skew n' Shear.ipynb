# %% [markdown]
# Get the data open

# %%
# !pip install Pillow
# Out:
# ...
# Cleaning up...

# %%
import h5py
import PIL
from PIL import Image
from IPython.display import Image as Image2

# container-specific paths

# %%
orig_path="/work/a01-000u-00.png"
form_path = ""
i = Image.open(orig_path)

# %%
i.crop?

# %%
j  = i.crop((408, 746, 408+1661, 746+89))

# %%
j.save("output.png")

# %%
Image2(orig_path)
